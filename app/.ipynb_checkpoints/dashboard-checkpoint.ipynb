# %%
import streamlit as st
import pandas as pd
import os

# Set the main configuration for the app
st.set_page_config(
    page_title="GrindGraph: Fitness Data Analytics",
    layout="wide",
    initial_sidebar_state="expanded"
)

# Function to load and merge data (REUSE YOUR NOTEBOOK CODE HERE!)
@st.cache_data
def load_data():
    # --- PATHS ---
    # Adjust these paths if your project structure is different!
    folder1 = "C:/GrindGraph/data/mturkfitbit_export_3.12.16-4.11.16/Fitabase Data 3.12.16-4.11.16"
    folder2 = "C:/GrindGraph/data/mturkfitbit_export_4.12.16-5.12.16/Fitabase Data 4.12.16-5.12.16"

    # Load and Merge Activity Data
    df1_activity = pd.read_csv(os.path.join(folder1, "dailyActivity_merged.csv"))
    df2_activity = pd.read_csv(os.path.join(folder2, "dailyActivity_merged.csv"))
    df = pd.concat([df1_activity, df2_activity], ignore_index=True)

    # Data Cleaning and Feature Engineering
    df.rename(columns={'ActivityDate': 'Date'}, inplace=True)
    df['Date'] = pd.to_datetime(df['Date'])
    df['Weekday'] = df['Date'].dt.day_name()

    # Note: You should ideally merge the sleep data here as well! 
    # (Copy the merge logic you perfected in your EDA notebook)

    return df

# Load the data
df = load_data()

# --- DASHBOARD LAYOUT ---

# Title Section
st.title("⚡ GrindGraph: Daily Activity Insights")
st.markdown("A portfolio project analyzing FitBit Fitness Tracker data.")

# Sidebar Filters (Example)
st.sidebar.header("Data Filter")

# Example 1: Date Range Selector
min_date = df['Date'].min().date()
max_date = df['Date'].max().date()
date_range = st.sidebar.date_input(
    "Select Date Range",
    value=(min_date, max_date),
    min_value=min_date,
    max_value=max_date
)

# Example 2: Activity Level Slider
max_steps = int(df['TotalSteps'].max())
step_filter = st.sidebar.slider(
    "Minimum Steps",
    min_value=0,
    max_value=max_steps,
    value=5000,
    step=500
)

# Apply filters to the DataFrame
if len(date_range) == 2:
    start_date, end_date = pd.to_datetime(date_range[0]), pd.to_datetime(date_range[1])
    df_filtered = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]
else:
    df_filtered = df

df_filtered = df_filtered[df_filtered['TotalSteps'] >= step_filter]


# Display the Filtered Data (Basic check)
st.subheader("Data Overview")
st.dataframe(df_filtered.head())

# Placeholder for Visualizations
st.subheader("Key Visualizations will go here!")
st.markdown("---")

# You will replace the placeholders below with the interactive plots next!
# Out:
# 2025-09-29 10:24:36.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.146 No runtime found, using MemoryCacheStorageManager
# 2025-09-29 10:24:36.148 No runtime found, using MemoryCacheStorageManager
# 2025-09-29 10:24:36.149 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.236 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.242 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.251 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.252 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.253 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.259 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.260 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.261 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.265 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.340 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.341 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.342 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.343 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.344 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 10:24:36.346 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
